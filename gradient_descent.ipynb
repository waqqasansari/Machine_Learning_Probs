# %% [markdown]
# <a href="https://colab.research.google.com/github/waqqasansari/Machine_Learning_Probs/blob/master/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
lr = 0.001
def batch_gd(x, y, lr):
  m_current = b_current = 0
  print('starting m , b:', m_current, b_current)
  iteration = 500
  n = len(x)
  learning_rate = lr
  for i in range(iteration):
    predicted_y = m_current*x + b_current
    cost = np.round(((1/n) * sum([val**2 for val in (y - predicted_y)])), 2)
    derivative_m = -(2/n) * sum(x*(y - predicted_y))
    derivative_b = -(2/n) * sum(y - predicted_y)
    m_current = np.round((m_current - learning_rate * derivative_m),2)
    b_current = np.round((b_current - learning_rate * derivative_b),2)
    print('m {}, b {}, cost {}, iteration {}'.format(m_current, b_current, cost, i))

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

batch_gd(x, y, lr)
# Out:
# starting m , b: 0 0
# m 0.06, b 0.02, cost 89.0, iteration 0
# m 0.12, b 0.04, cost 84.97, iteration 1
# m 0.18, b 0.06, cost 81.03, iteration 2
# m 0.24, b 0.08, cost 77.18, iteration 3
# m 0.3, b 0.1, cost 73.44, iteration 4
# m 0.35, b 0.12, cost 69.78, iteration 5
# m 0.4, b 0.14, cost 66.75, iteration 6
# m 0.45, b 0.16, cost 63.8, iteration 7
# m 0.5, b 0.17, cost 60.91, iteration 8
# m 0.55, b 0.18, cost 58.23, iteration 9
# m 0.6, b 0.19, cost 55.61, iteration 10
# m 0.65, b 0.2, cost 53.06, iteration 11
# m 0.7, b 0.21, cost 50.57, iteration 12
# m 0.75, b 0.22, cost 48.14, iteration 13
# m 0.79, b 0.23, cost 45.77, iteration 14
# m 0.83, b 0.24, cost 43.89, iteration 15
# m 0.87, b 0.25, cost 42.05, iteration 16
# m 0.91, b 0.26, cost 40.25, iteration 17
# m 0.95, b 0.27, cost 38.5, iteration 18
# m 0.99, b 0.28, cost 36.78, iteration 19
# m 1.03, b 0.29, cost 35.1, iteration 20
# m 1.07, b 0.3, cost 33.47, iteration 21
# m 1.11, b 0.31, cost 31.87, iteration 22
# m 1.15, b 0.32, cost 30.31, iteration 23
# m 1.18, b 0.33, cost 28.8, iteration 24
# m 1.21, b 0.34, cost 27.66, iteration 25
# m 1.24, b 0.35, cost 26.55, iteration 26
# m 1.27, b 0.36, cost 25.46, iteration 27
# m 1.3, b 0.37, cost 24.39, iteration 28
# m 1.33, b 0.38, cost 23.35, iteration 29
# m 1.36, b 0.39, cost 22.33, iteration 30
# m 1.39, b 0.4, cost 21.34, iteration 31
# m 1.42, b 0.41, cost 20.37, iteration 32
# m 1.45, b 0.42, cost 19.42, iteration 33
# m 1.48, b 0.43, cost 18.5, iteration 34
# m 1.51, b 0.44, cost 17.6, iteration 35
# m 1.54, b 0.45, cost 16.72, iteration 36
# m 1.57, b 0.46, cost 15.87, iteration 37
# m 1.59, b 0.47, cost 15.04, iteration 38
# m 1.61, b 0.48, cost 14.47, iteration 39
# m 1.63, b 0.49, cost 13.92, iteration 40
# m 1.65, b 0.5, cost 13.38, iteration 41
# m 1.67, b 0.51, cost 12.85, iteration 42
# m 1.69, b 0.52, cost 12.33, iteration 43
# m 1.71, b 0.53, cost 11.82, iteration 44
# m 1.73, b 0.54, cost 11.32, iteration 45
# m 1.75, b 0.55, cost 10.84, iteration 46
# m 1.77, b 0.56, cost 10.37, iteration 47
# m 1.79, b 0.57, cost 9.9, iteration 48
# m 1.81, b 0.58, cost 9.45, iteration 49
# m 1.83, b 0.59, cost 9.01, iteration 50
# m 1.85, b 0.6, cost 8.58, iteration 51
# m 1.87, b 0.61, cost 8.17, iteration 52
# m 1.89, b 0.62, cost 7.76, iteration 53
# m 1.91, b 0.63, cost 7.37, iteration 54
# m 1.93, b 0.64, cost 6.99, iteration 55
# m 1.95, b 0.65, cost 6.61, iteration 56
# m 1.97, b 0.66, cost 6.26, iteration 57
# m 1.98, b 0.66, cost 5.91, iteration 58
# m 1.99, b 0.66, cost 5.76, iteration 59
# m 2.0, b 0.66, cost 5.62, iteration 60
# m 2.01, b 0.66, cost 5.48, iteration 61
# m 2.02, b 0.66, cost 5.34, iteration 62
# m 2.03, b 0.66, cost 5.2, iteration 63
# m 2.04, b 0.66, cost 5.06, iteration 64
# m 2.05, b 0.66, cost 4.93, iteration 65
# m 2.06, b 0.66, cost 4.8, iteration 66
# m 2.07, b 0.66, cost 4.67, iteration 67
# m 2.08, b 0.66, cost 4.55, iteration 68
# m 2.09, b 0.66, cost 4.42, iteration 69
# m 2.1, b 0.66, cost 4.3, iteration 70
# m 2.11, b 0.66, cost 4.18, iteration 71
# m 2.12, b 0.66, cost 4.06, iteration 72
# m 2.13, b 0.66, cost 3.95, iteration 73
# m 2.14, b 0.66, cost 3.84, iteration 74
# m 2.15, b 0.66, cost 3.73, iteration 75
# m 2.16, b 0.66, cost 3.62, iteration 76
# m 2.17, b 0.66, cost 3.51, iteration 77
# m 2.18, b 0.66, cost 3.41, iteration 78
# m 2.19, b 0.66, cost 3.3, iteration 79
# m 2.2, b 0.66, cost 3.21, iteration 80
# m 2.21, b 0.66, cost 3.11, iteration 81
# m 2.22, b 0.66, cost 3.01, iteration 82
# m 2.23, b 0.66, cost 2.92, iteration 83
# m 2.24, b 0.66, cost 2.83, iteration 84
# m 2.25, b 0.66, cost 2.74, iteration 85
# m 2.26, b 0.66, cost 2.65, iteration 86
# m 2.27, b 0.66, cost 2.57, iteration 87
# m 2.28, b 0.66, cost 2.49, iteration 88
# m 2.29, b 0.66, cost 2.41, iteration 89
# m 2.3, b 0.66, cost 2.33, iteration 90
# m 2.31, b 0.66, cost 2.25, iteration 91
# m 2.32, b 0.66, cost 2.18, iteration 92
# m 2.33, b 0.66, cost 2.11, iteration 93
# m 2.34, b 0.66, cost 2.04, iteration 94
# m 2.35, b 0.66, cost 1.97, iteration 95
# m 2.36, b 0.66, cost 1.91, iteration 96
# m 2.37, b 0.66, cost 1.85, iteration 97
# m 2.38, b 0.66, cost 1.79, iteration 98
# m 2.39, b 0.66, cost 1.73, iteration 99
# m 2.4, b 0.66, cost 1.67, iteration 100
# m 2.41, b 0.66, cost 1.62, iteration 101
# m 2.42, b 0.66, cost 1.57, iteration 102
# m 2.42, b 0.66, cost 1.52, iteration 103
# m 2.42, b 0.66, cost 1.52, iteration 104
# m 2.42, b 0.66, cost 1.52, iteration 105
# m 2.42, b 0.66, cost 1.52, iteration 106
# m 2.42, b 0.66, cost 1.52, iteration 107
# m 2.42, b 0.66, cost 1.52, iteration 108
# m 2.42, b 0.66, cost 1.52, iteration 109
# m 2.42, b 0.66, cost 1.52, iteration 110
# m 2.42, b 0.66, cost 1.52, iteration 111
# m 2.42, b 0.66, cost 1.52, iteration 112
# m 2.42, b 0.66, cost 1.52, iteration 113
# m 2.42, b 0.66, cost 1.52, iteration 114
# m 2.42, b 0.66, cost 1.52, iteration 115
# m 2.42, b 0.66, cost 1.52, iteration 116
# m 2.42, b 0.66, cost 1.52, iteration 117
# m 2.42, b 0.66, cost 1.52, iteration 118
# m 2.42, b 0.66, cost 1.52, iteration 119
# m 2.42, b 0.66, cost 1.52, iteration 120
# m 2.42, b 0.66, cost 1.52, iteration 121
# m 2.42, b 0.66, cost 1.52, iteration 122
# m 2.42, b 0.66, cost 1.52, iteration 123
# m 2.42, b 0.66, cost 1.52, iteration 124
# m 2.42, b 0.66, cost 1.52, iteration 125
# m 2.42, b 0.66, cost 1.52, iteration 126
# m 2.42, b 0.66, cost 1.52, iteration 127
# m 2.42, b 0.66, cost 1.52, iteration 128
# m 2.42, b 0.66, cost 1.52, iteration 129
# m 2.42, b 0.66, cost 1.52, iteration 130
# m 2.42, b 0.66, cost 1.52, iteration 131
# m 2.42, b 0.66, cost 1.52, iteration 132
# m 2.42, b 0.66, cost 1.52, iteration 133
# m 2.42, b 0.66, cost 1.52, iteration 134
# m 2.42, b 0.66, cost 1.52, iteration 135
# m 2.42, b 0.66, cost 1.52, iteration 136
# m 2.42, b 0.66, cost 1.52, iteration 137
# m 2.42, b 0.66, cost 1.52, iteration 138
# m 2.42, b 0.66, cost 1.52, iteration 139
# m 2.42, b 0.66, cost 1.52, iteration 140
# m 2.42, b 0.66, cost 1.52, iteration 141
# m 2.42, b 0.66, cost 1.52, iteration 142
# m 2.42, b 0.66, cost 1.52, iteration 143
# m 2.42, b 0.66, cost 1.52, iteration 144
# m 2.42, b 0.66, cost 1.52, iteration 145
# m 2.42, b 0.66, cost 1.52, iteration 146
# m 2.42, b 0.66, cost 1.52, iteration 147
# m 2.42, b 0.66, cost 1.52, iteration 148
# m 2.42, b 0.66, cost 1.52, iteration 149
# m 2.42, b 0.66, cost 1.52, iteration 150
# m 2.42, b 0.66, cost 1.52, iteration 151
# m 2.42, b 0.66, cost 1.52, iteration 152
# m 2.42, b 0.66, cost 1.52, iteration 153
# m 2.42, b 0.66, cost 1.52, iteration 154
# m 2.42, b 0.66, cost 1.52, iteration 155
# m 2.42, b 0.66, cost 1.52, iteration 156
# m 2.42, b 0.66, cost 1.52, iteration 157
# m 2.42, b 0.66, cost 1.52, iteration 158
# m 2.42, b 0.66, cost 1.52, iteration 159
# m 2.42, b 0.66, cost 1.52, iteration 160
# m 2.42, b 0.66, cost 1.52, iteration 161
# m 2.42, b 0.66, cost 1.52, iteration 162
# m 2.42, b 0.66, cost 1.52, iteration 163
# m 2.42, b 0.66, cost 1.52, iteration 164
# m 2.42, b 0.66, cost 1.52, iteration 165
# m 2.42, b 0.66, cost 1.52, iteration 166
# m 2.42, b 0.66, cost 1.52, iteration 167
# m 2.42, b 0.66, cost 1.52, iteration 168
# m 2.42, b 0.66, cost 1.52, iteration 169
# m 2.42, b 0.66, cost 1.52, iteration 170
# m 2.42, b 0.66, cost 1.52, iteration 171
# m 2.42, b 0.66, cost 1.52, iteration 172
# m 2.42, b 0.66, cost 1.52, iteration 173
# m 2.42, b 0.66, cost 1.52, iteration 174
# m 2.42, b 0.66, cost 1.52, iteration 175
# m 2.42, b 0.66, cost 1.52, iteration 176
# m 2.42, b 0.66, cost 1.52, iteration 177
# m 2.42, b 0.66, cost 1.52, iteration 178
# m 2.42, b 0.66, cost 1.52, iteration 179
# m 2.42, b 0.66, cost 1.52, iteration 180
# m 2.42, b 0.66, cost 1.52, iteration 181
# m 2.42, b 0.66, cost 1.52, iteration 182
# m 2.42, b 0.66, cost 1.52, iteration 183
# m 2.42, b 0.66, cost 1.52, iteration 184
# m 2.42, b 0.66, cost 1.52, iteration 185
# m 2.42, b 0.66, cost 1.52, iteration 186
# m 2.42, b 0.66, cost 1.52, iteration 187
# m 2.42, b 0.66, cost 1.52, iteration 188
# m 2.42, b 0.66, cost 1.52, iteration 189
# m 2.42, b 0.66, cost 1.52, iteration 190
# m 2.42, b 0.66, cost 1.52, iteration 191
# m 2.42, b 0.66, cost 1.52, iteration 192
# m 2.42, b 0.66, cost 1.52, iteration 193
# m 2.42, b 0.66, cost 1.52, iteration 194
# m 2.42, b 0.66, cost 1.52, iteration 195
# m 2.42, b 0.66, cost 1.52, iteration 196
# m 2.42, b 0.66, cost 1.52, iteration 197
# m 2.42, b 0.66, cost 1.52, iteration 198
# m 2.42, b 0.66, cost 1.52, iteration 199
# m 2.42, b 0.66, cost 1.52, iteration 200
# m 2.42, b 0.66, cost 1.52, iteration 201
# m 2.42, b 0.66, cost 1.52, iteration 202
# m 2.42, b 0.66, cost 1.52, iteration 203
# m 2.42, b 0.66, cost 1.52, iteration 204
# m 2.42, b 0.66, cost 1.52, iteration 205
# m 2.42, b 0.66, cost 1.52, iteration 206
# m 2.42, b 0.66, cost 1.52, iteration 207
# m 2.42, b 0.66, cost 1.52, iteration 208
# m 2.42, b 0.66, cost 1.52, iteration 209
# m 2.42, b 0.66, cost 1.52, iteration 210
# m 2.42, b 0.66, cost 1.52, iteration 211
# m 2.42, b 0.66, cost 1.52, iteration 212
# m 2.42, b 0.66, cost 1.52, iteration 213
# m 2.42, b 0.66, cost 1.52, iteration 214
# m 2.42, b 0.66, cost 1.52, iteration 215
# m 2.42, b 0.66, cost 1.52, iteration 216
# m 2.42, b 0.66, cost 1.52, iteration 217
# m 2.42, b 0.66, cost 1.52, iteration 218
# m 2.42, b 0.66, cost 1.52, iteration 219
# m 2.42, b 0.66, cost 1.52, iteration 220
# m 2.42, b 0.66, cost 1.52, iteration 221
# m 2.42, b 0.66, cost 1.52, iteration 222
# m 2.42, b 0.66, cost 1.52, iteration 223
# m 2.42, b 0.66, cost 1.52, iteration 224
# m 2.42, b 0.66, cost 1.52, iteration 225
# m 2.42, b 0.66, cost 1.52, iteration 226
# m 2.42, b 0.66, cost 1.52, iteration 227
# m 2.42, b 0.66, cost 1.52, iteration 228
# m 2.42, b 0.66, cost 1.52, iteration 229
# m 2.42, b 0.66, cost 1.52, iteration 230
# m 2.42, b 0.66, cost 1.52, iteration 231
# m 2.42, b 0.66, cost 1.52, iteration 232
# m 2.42, b 0.66, cost 1.52, iteration 233
# m 2.42, b 0.66, cost 1.52, iteration 234
# m 2.42, b 0.66, cost 1.52, iteration 235
# m 2.42, b 0.66, cost 1.52, iteration 236
# m 2.42, b 0.66, cost 1.52, iteration 237
# m 2.42, b 0.66, cost 1.52, iteration 238
# m 2.42, b 0.66, cost 1.52, iteration 239
# m 2.42, b 0.66, cost 1.52, iteration 240
# m 2.42, b 0.66, cost 1.52, iteration 241
# m 2.42, b 0.66, cost 1.52, iteration 242
# m 2.42, b 0.66, cost 1.52, iteration 243
# m 2.42, b 0.66, cost 1.52, iteration 244
# m 2.42, b 0.66, cost 1.52, iteration 245
# m 2.42, b 0.66, cost 1.52, iteration 246
# m 2.42, b 0.66, cost 1.52, iteration 247
# m 2.42, b 0.66, cost 1.52, iteration 248
# m 2.42, b 0.66, cost 1.52, iteration 249
# m 2.42, b 0.66, cost 1.52, iteration 250
# m 2.42, b 0.66, cost 1.52, iteration 251
# m 2.42, b 0.66, cost 1.52, iteration 252
# m 2.42, b 0.66, cost 1.52, iteration 253
# m 2.42, b 0.66, cost 1.52, iteration 254
# m 2.42, b 0.66, cost 1.52, iteration 255
# m 2.42, b 0.66, cost 1.52, iteration 256
# m 2.42, b 0.66, cost 1.52, iteration 257
# m 2.42, b 0.66, cost 1.52, iteration 258
# m 2.42, b 0.66, cost 1.52, iteration 259
# m 2.42, b 0.66, cost 1.52, iteration 260
# m 2.42, b 0.66, cost 1.52, iteration 261
# m 2.42, b 0.66, cost 1.52, iteration 262
# m 2.42, b 0.66, cost 1.52, iteration 263
# m 2.42, b 0.66, cost 1.52, iteration 264
# m 2.42, b 0.66, cost 1.52, iteration 265
# m 2.42, b 0.66, cost 1.52, iteration 266
# m 2.42, b 0.66, cost 1.52, iteration 267
# m 2.42, b 0.66, cost 1.52, iteration 268
# m 2.42, b 0.66, cost 1.52, iteration 269
# m 2.42, b 0.66, cost 1.52, iteration 270
# m 2.42, b 0.66, cost 1.52, iteration 271
# m 2.42, b 0.66, cost 1.52, iteration 272
# m 2.42, b 0.66, cost 1.52, iteration 273
# m 2.42, b 0.66, cost 1.52, iteration 274
# m 2.42, b 0.66, cost 1.52, iteration 275
# m 2.42, b 0.66, cost 1.52, iteration 276
# m 2.42, b 0.66, cost 1.52, iteration 277
# m 2.42, b 0.66, cost 1.52, iteration 278
# m 2.42, b 0.66, cost 1.52, iteration 279
# m 2.42, b 0.66, cost 1.52, iteration 280
# m 2.42, b 0.66, cost 1.52, iteration 281
# m 2.42, b 0.66, cost 1.52, iteration 282
# m 2.42, b 0.66, cost 1.52, iteration 283
# m 2.42, b 0.66, cost 1.52, iteration 284
# m 2.42, b 0.66, cost 1.52, iteration 285
# m 2.42, b 0.66, cost 1.52, iteration 286
# m 2.42, b 0.66, cost 1.52, iteration 287
# m 2.42, b 0.66, cost 1.52, iteration 288
# m 2.42, b 0.66, cost 1.52, iteration 289
# m 2.42, b 0.66, cost 1.52, iteration 290
# m 2.42, b 0.66, cost 1.52, iteration 291
# m 2.42, b 0.66, cost 1.52, iteration 292
# m 2.42, b 0.66, cost 1.52, iteration 293
# m 2.42, b 0.66, cost 1.52, iteration 294
# m 2.42, b 0.66, cost 1.52, iteration 295
# m 2.42, b 0.66, cost 1.52, iteration 296
# m 2.42, b 0.66, cost 1.52, iteration 297
# m 2.42, b 0.66, cost 1.52, iteration 298
# m 2.42, b 0.66, cost 1.52, iteration 299
# m 2.42, b 0.66, cost 1.52, iteration 300
# m 2.42, b 0.66, cost 1.52, iteration 301
# m 2.42, b 0.66, cost 1.52, iteration 302
# m 2.42, b 0.66, cost 1.52, iteration 303
# m 2.42, b 0.66, cost 1.52, iteration 304
# m 2.42, b 0.66, cost 1.52, iteration 305
# m 2.42, b 0.66, cost 1.52, iteration 306
# m 2.42, b 0.66, cost 1.52, iteration 307
# m 2.42, b 0.66, cost 1.52, iteration 308
# m 2.42, b 0.66, cost 1.52, iteration 309
# m 2.42, b 0.66, cost 1.52, iteration 310
# m 2.42, b 0.66, cost 1.52, iteration 311
# m 2.42, b 0.66, cost 1.52, iteration 312
# m 2.42, b 0.66, cost 1.52, iteration 313
# m 2.42, b 0.66, cost 1.52, iteration 314
# m 2.42, b 0.66, cost 1.52, iteration 315
# m 2.42, b 0.66, cost 1.52, iteration 316
# m 2.42, b 0.66, cost 1.52, iteration 317
# m 2.42, b 0.66, cost 1.52, iteration 318
# m 2.42, b 0.66, cost 1.52, iteration 319
# m 2.42, b 0.66, cost 1.52, iteration 320
# m 2.42, b 0.66, cost 1.52, iteration 321
# m 2.42, b 0.66, cost 1.52, iteration 322
# m 2.42, b 0.66, cost 1.52, iteration 323
# m 2.42, b 0.66, cost 1.52, iteration 324
# m 2.42, b 0.66, cost 1.52, iteration 325
# m 2.42, b 0.66, cost 1.52, iteration 326
# m 2.42, b 0.66, cost 1.52, iteration 327
# m 2.42, b 0.66, cost 1.52, iteration 328
# m 2.42, b 0.66, cost 1.52, iteration 329
# m 2.42, b 0.66, cost 1.52, iteration 330
# m 2.42, b 0.66, cost 1.52, iteration 331
# m 2.42, b 0.66, cost 1.52, iteration 332
# m 2.42, b 0.66, cost 1.52, iteration 333
# m 2.42, b 0.66, cost 1.52, iteration 334
# m 2.42, b 0.66, cost 1.52, iteration 335
# m 2.42, b 0.66, cost 1.52, iteration 336
# m 2.42, b 0.66, cost 1.52, iteration 337
# m 2.42, b 0.66, cost 1.52, iteration 338
# m 2.42, b 0.66, cost 1.52, iteration 339
# m 2.42, b 0.66, cost 1.52, iteration 340
# m 2.42, b 0.66, cost 1.52, iteration 341
# m 2.42, b 0.66, cost 1.52, iteration 342
# m 2.42, b 0.66, cost 1.52, iteration 343
# m 2.42, b 0.66, cost 1.52, iteration 344
# m 2.42, b 0.66, cost 1.52, iteration 345
# m 2.42, b 0.66, cost 1.52, iteration 346
# m 2.42, b 0.66, cost 1.52, iteration 347
# m 2.42, b 0.66, cost 1.52, iteration 348
# m 2.42, b 0.66, cost 1.52, iteration 349
# m 2.42, b 0.66, cost 1.52, iteration 350
# m 2.42, b 0.66, cost 1.52, iteration 351
# m 2.42, b 0.66, cost 1.52, iteration 352
# m 2.42, b 0.66, cost 1.52, iteration 353
# m 2.42, b 0.66, cost 1.52, iteration 354
# m 2.42, b 0.66, cost 1.52, iteration 355
# m 2.42, b 0.66, cost 1.52, iteration 356
# m 2.42, b 0.66, cost 1.52, iteration 357
# m 2.42, b 0.66, cost 1.52, iteration 358
# m 2.42, b 0.66, cost 1.52, iteration 359
# m 2.42, b 0.66, cost 1.52, iteration 360
# m 2.42, b 0.66, cost 1.52, iteration 361
# m 2.42, b 0.66, cost 1.52, iteration 362
# m 2.42, b 0.66, cost 1.52, iteration 363
# m 2.42, b 0.66, cost 1.52, iteration 364
# m 2.42, b 0.66, cost 1.52, iteration 365
# m 2.42, b 0.66, cost 1.52, iteration 366
# m 2.42, b 0.66, cost 1.52, iteration 367
# m 2.42, b 0.66, cost 1.52, iteration 368
# m 2.42, b 0.66, cost 1.52, iteration 369
# m 2.42, b 0.66, cost 1.52, iteration 370
# m 2.42, b 0.66, cost 1.52, iteration 371
# m 2.42, b 0.66, cost 1.52, iteration 372
# m 2.42, b 0.66, cost 1.52, iteration 373
# m 2.42, b 0.66, cost 1.52, iteration 374
# m 2.42, b 0.66, cost 1.52, iteration 375
# m 2.42, b 0.66, cost 1.52, iteration 376
# m 2.42, b 0.66, cost 1.52, iteration 377
# m 2.42, b 0.66, cost 1.52, iteration 378
# m 2.42, b 0.66, cost 1.52, iteration 379
# m 2.42, b 0.66, cost 1.52, iteration 380
# m 2.42, b 0.66, cost 1.52, iteration 381
# m 2.42, b 0.66, cost 1.52, iteration 382
# m 2.42, b 0.66, cost 1.52, iteration 383
# m 2.42, b 0.66, cost 1.52, iteration 384
# m 2.42, b 0.66, cost 1.52, iteration 385
# m 2.42, b 0.66, cost 1.52, iteration 386
# m 2.42, b 0.66, cost 1.52, iteration 387
# m 2.42, b 0.66, cost 1.52, iteration 388
# m 2.42, b 0.66, cost 1.52, iteration 389
# m 2.42, b 0.66, cost 1.52, iteration 390
# m 2.42, b 0.66, cost 1.52, iteration 391
# m 2.42, b 0.66, cost 1.52, iteration 392
# m 2.42, b 0.66, cost 1.52, iteration 393
# m 2.42, b 0.66, cost 1.52, iteration 394
# m 2.42, b 0.66, cost 1.52, iteration 395
# m 2.42, b 0.66, cost 1.52, iteration 396
# m 2.42, b 0.66, cost 1.52, iteration 397
# m 2.42, b 0.66, cost 1.52, iteration 398
# m 2.42, b 0.66, cost 1.52, iteration 399
# m 2.42, b 0.66, cost 1.52, iteration 400
# m 2.42, b 0.66, cost 1.52, iteration 401
# m 2.42, b 0.66, cost 1.52, iteration 402
# m 2.42, b 0.66, cost 1.52, iteration 403
# m 2.42, b 0.66, cost 1.52, iteration 404
# m 2.42, b 0.66, cost 1.52, iteration 405
# m 2.42, b 0.66, cost 1.52, iteration 406
# m 2.42, b 0.66, cost 1.52, iteration 407
# m 2.42, b 0.66, cost 1.52, iteration 408
# m 2.42, b 0.66, cost 1.52, iteration 409
# m 2.42, b 0.66, cost 1.52, iteration 410
# m 2.42, b 0.66, cost 1.52, iteration 411
# m 2.42, b 0.66, cost 1.52, iteration 412
# m 2.42, b 0.66, cost 1.52, iteration 413
# m 2.42, b 0.66, cost 1.52, iteration 414
# m 2.42, b 0.66, cost 1.52, iteration 415
# m 2.42, b 0.66, cost 1.52, iteration 416
# m 2.42, b 0.66, cost 1.52, iteration 417
# m 2.42, b 0.66, cost 1.52, iteration 418
# m 2.42, b 0.66, cost 1.52, iteration 419
# m 2.42, b 0.66, cost 1.52, iteration 420
# m 2.42, b 0.66, cost 1.52, iteration 421
# m 2.42, b 0.66, cost 1.52, iteration 422
# m 2.42, b 0.66, cost 1.52, iteration 423
# m 2.42, b 0.66, cost 1.52, iteration 424
# m 2.42, b 0.66, cost 1.52, iteration 425
# m 2.42, b 0.66, cost 1.52, iteration 426
# m 2.42, b 0.66, cost 1.52, iteration 427
# m 2.42, b 0.66, cost 1.52, iteration 428
# m 2.42, b 0.66, cost 1.52, iteration 429
# m 2.42, b 0.66, cost 1.52, iteration 430
# m 2.42, b 0.66, cost 1.52, iteration 431
# m 2.42, b 0.66, cost 1.52, iteration 432
# m 2.42, b 0.66, cost 1.52, iteration 433
# m 2.42, b 0.66, cost 1.52, iteration 434
# m 2.42, b 0.66, cost 1.52, iteration 435
# m 2.42, b 0.66, cost 1.52, iteration 436
# m 2.42, b 0.66, cost 1.52, iteration 437
# m 2.42, b 0.66, cost 1.52, iteration 438
# m 2.42, b 0.66, cost 1.52, iteration 439
# m 2.42, b 0.66, cost 1.52, iteration 440
# m 2.42, b 0.66, cost 1.52, iteration 441
# m 2.42, b 0.66, cost 1.52, iteration 442
# m 2.42, b 0.66, cost 1.52, iteration 443
# m 2.42, b 0.66, cost 1.52, iteration 444
# m 2.42, b 0.66, cost 1.52, iteration 445
# m 2.42, b 0.66, cost 1.52, iteration 446
# m 2.42, b 0.66, cost 1.52, iteration 447
# m 2.42, b 0.66, cost 1.52, iteration 448
# m 2.42, b 0.66, cost 1.52, iteration 449
# m 2.42, b 0.66, cost 1.52, iteration 450
# m 2.42, b 0.66, cost 1.52, iteration 451
# m 2.42, b 0.66, cost 1.52, iteration 452
# m 2.42, b 0.66, cost 1.52, iteration 453
# m 2.42, b 0.66, cost 1.52, iteration 454
# m 2.42, b 0.66, cost 1.52, iteration 455
# m 2.42, b 0.66, cost 1.52, iteration 456
# m 2.42, b 0.66, cost 1.52, iteration 457
# m 2.42, b 0.66, cost 1.52, iteration 458
# m 2.42, b 0.66, cost 1.52, iteration 459
# m 2.42, b 0.66, cost 1.52, iteration 460
# m 2.42, b 0.66, cost 1.52, iteration 461
# m 2.42, b 0.66, cost 1.52, iteration 462
# m 2.42, b 0.66, cost 1.52, iteration 463
# m 2.42, b 0.66, cost 1.52, iteration 464
# m 2.42, b 0.66, cost 1.52, iteration 465
# m 2.42, b 0.66, cost 1.52, iteration 466
# m 2.42, b 0.66, cost 1.52, iteration 467
# m 2.42, b 0.66, cost 1.52, iteration 468
# m 2.42, b 0.66, cost 1.52, iteration 469
# m 2.42, b 0.66, cost 1.52, iteration 470
# m 2.42, b 0.66, cost 1.52, iteration 471
# m 2.42, b 0.66, cost 1.52, iteration 472
# m 2.42, b 0.66, cost 1.52, iteration 473
# m 2.42, b 0.66, cost 1.52, iteration 474
# m 2.42, b 0.66, cost 1.52, iteration 475
# m 2.42, b 0.66, cost 1.52, iteration 476
# m 2.42, b 0.66, cost 1.52, iteration 477
# m 2.42, b 0.66, cost 1.52, iteration 478
# m 2.42, b 0.66, cost 1.52, iteration 479
# m 2.42, b 0.66, cost 1.52, iteration 480
# m 2.42, b 0.66, cost 1.52, iteration 481
# m 2.42, b 0.66, cost 1.52, iteration 482
# m 2.42, b 0.66, cost 1.52, iteration 483
# m 2.42, b 0.66, cost 1.52, iteration 484
# m 2.42, b 0.66, cost 1.52, iteration 485
# m 2.42, b 0.66, cost 1.52, iteration 486
# m 2.42, b 0.66, cost 1.52, iteration 487
# m 2.42, b 0.66, cost 1.52, iteration 488
# m 2.42, b 0.66, cost 1.52, iteration 489
# m 2.42, b 0.66, cost 1.52, iteration 490
# m 2.42, b 0.66, cost 1.52, iteration 491
# m 2.42, b 0.66, cost 1.52, iteration 492
# m 2.42, b 0.66, cost 1.52, iteration 493
# m 2.42, b 0.66, cost 1.52, iteration 494
# m 2.42, b 0.66, cost 1.52, iteration 495
# m 2.42, b 0.66, cost 1.52, iteration 496
# m 2.42, b 0.66, cost 1.52, iteration 497
# m 2.42, b 0.66, cost 1.52, iteration 498
# m 2.42, b 0.66, cost 1.52, iteration 499
